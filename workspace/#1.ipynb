# %%
import pandas as pd
import numpy as np
import datetime as dt
import json
from libs.fxcm_libs import fxcm_rest_api_token as fxcm_rest_api

# %%
api_token = "d808da394895605e414394e79c1a3c9ffafad862"
server = "demo"

trader = fxcm_rest_api.Trader(api_token, server) 
trader.login()
# Out:
# {'status': True, 'data': 'Connecting'}
# Websocket connected: joulCYYQ5Woxd89bABvZ

# %%
def get_tick(tick):
    dict_tick = json.loads(tick)
    print({"Datetime": dict_tick['Updated'], 'Bid': dict_tick['Rates'][0]})

# %%
trader.subscribe("GBP/USD", handler=get_tick)
# Out:
# {'Datetime': 1651519431738, 'Bid': 1.05075}
# {'status': True, 'response': {'executed': True}}
# {'Datetime': 1651519432266, 'Bid': 1.0507600000000001}
# {'Datetime': 1651519432227, 'Bid': 1.24875}
# {'Datetime': 1651519432605, 'Bid': 1.05075}
# {'Datetime': 1651519432851, 'Bid': 1.2487300000000001}
# {'Datetime': 1651519433353, 'Bid': 1.05072}
# {'Datetime': 1651519433308, 'Bid': 1.2487000000000001}
# {'Datetime': 1651519433836, 'Bid': 1.05072}
# {'Datetime': 1651519433827, 'Bid': 1.24869}
# {'Datetime': 1651519434207, 'Bid': 1.05072}
# {'Datetime': 1651519434742, 'Bid': 1.05071}
# {'Datetime': 1651519435606, 'Bid': 1.05071}{'Datetime': 1651519435740, 'Bid': 1.24866}
#
# {'Datetime': 1651519436065, 'Bid': 1.05072}
# {'Datetime': 1651519436031, 'Bid': 1.24865}
# {'Datetime': 1651519436756, 'Bid': 1.24865}
# {'Datetime': 1651519437132, 'Bid': 1.24866}
# {'Datetime': 1651519437728, 'Bid': 1.24865}
# {'Datetime': 1651519438055, 'Bid': 1.05072}
# {'Datetime': 1651519438444, 'Bid': 1.05072}
# {'Datetime': 1651519439001, 'Bid': 1.05071}
# {'Datetime': 1651519439521, 'Bid': 1.05072}
# {'Datetime': 1651519440234, 'Bid': 1.24864}
# {'Datetime': 1651519440853, 'Bid': 1.05068}
# {'Datetime': 1651519440848, 'Bid': 1.24862}
# {'Datetime': 1651519441294, 'Bid': 1.05068}
# {'Datetime': 1651519441105, 'Bid': 1.2486}
# {'Datetime': 1651519441703, 'Bid': 1.24858}
# {'Datetime': 1651519442094, 'Bid': 1.05072}
# {'Datetime': 1651519442086, 'Bid': 1.24866}
# {'Datetime': 1651519443333, 'Bid': 1.24864}
# {'Datetime': 1651519443605, 'Bid': 1.24865}
# {'Datetime': 1651519444273, 'Bid': 1.24864}
# {'Datetime': 1651519444646, 'Bid': 1.24865}
# {'Datetime': 1651519445013, 'Bid': 1.24864}
# {'Datetime': 1651519445995, 'Bid': 1.24865}
# {'Datetime': 1651519446789, 'Bid': 1.05072}
# {'Datetime': 1651519446588, 'Bid': 1.24864}
# {'Datetime': 1651519450851, 'Bid': 1.24862}
# {'Datetime': 1651519451196, 'Bid': 1.0507}
# {'Datetime': 1651519451058, 'Bid': 1.24859}
# {'Datetime': 1651519451693, 'Bid': 1.0507}
# {'Datetime': 1651519451693, 'Bid': 1.24861}
# {'Datetime': 1651519452247, 'Bid': 1.0507}
# {'Datetime': 1651519452548, 'Bid': 1.24861}
# {'Datetime': 1651519453525, 'Bid': 1.05071}
# {'Datetime': 1651519453517, 'Bid': 1.24861}
# {'Datetime': 1651519454592, 'Bid': 1.05071}
# {'Datetime': 1651519454603, 'Bid': 1.24861}
# {'Datetime': 1651519455331, 'Bid': 1.0507}
# {'Datetime': 1651519455337, 'Bid': 1.24861}
# {'Datetime': 1651519455821, 'Bid': 1.24858}
# {'Datetime': 1651519456051, 'Bid': 1.24857}
# {'Datetime': 1651519457250, 'Bid': 1.05071}
# {'Datetime': 1651519457332, 'Bid': 1.24859}
# {'Datetime': 1651519457819, 'Bid': 1.0507}
# {'Datetime': 1651519458303, 'Bid': 1.05072}
# {'Datetime': 1651519458105, 'Bid': 1.24861}
# {'Datetime': 1651519459036, 'Bid': 1.05074}
# {'Datetime': 1651519459083, 'Bid': 1.24866}
# {'Datetime': 1651519459851, 'Bid': 1.24862}
# {'Datetime': 1651519460290, 'Bid': 1.05074}
# {'Datetime': 1651519460285, 'Bid': 1.24867}
# {'Datetime': 1651519460756, 'Bid': 1.05075}
# {'Datetime': 1651519460774, 'Bid': 1.24868}
# {'Datetime': 1651519461078, 'Bid': 1.05074}
# {'Datetime': 1651519461349, 'Bid': 1.24867}
# {'Datetime': 1651519462332, 'Bid': 1.0507600000000001}
# {'Datetime': 1651519462316, 'Bid': 1.24871}
# {'Datetime': 1651519462609, 'Bid': 1.05075}
# {'Datetime': 1651519463328, 'Bid': 1.2487000000000001}
# {'Datetime': 1651519465825, 'Bid': 1.05077}
# {'Datetime': 1651519466100, 'Bid': 1.2487000000000001}
# {'Datetime': 1651519466314, 'Bid': 1.05075}
# {'Datetime': 1651519466734, 'Bid': 1.2487000000000001}
# {'Datetime': 1651519466791, 'Bid': 1.05075}
# {'Datetime': 1651519468790, 'Bid': 1.05077}
# {'Datetime': 1651519468765, 'Bid': 1.24872}
# {'Datetime': 1651519469306, 'Bid': 1.05077}
# {'Datetime': 1651519469345, 'Bid': 1.2487000000000001}
# {'Datetime': 1651519469627, 'Bid': 1.24871}
# {'Datetime': 1651519470294, 'Bid': 1.05077}
# {'Datetime': 1651519470816, 'Bid': 1.05077}
# {'Datetime': 1651519471095, 'Bid': 1.0507900000000001}
# {'Datetime': 1651519471348, 'Bid': 1.2487300000000001}
# {'Datetime': 1651519471853, 'Bid': 1.05083}
# {'Datetime': 1651519471832, 'Bid': 1.24876}
# {'Datetime': 1651519472252, 'Bid': 1.05083}
# {'Datetime': 1651519472564, 'Bid': 1.05083}
# {'Datetime': 1651519473791, 'Bid': 1.0508600000000001}
# {'Datetime': 1651519474038, 'Bid': 1.05085}
# {'Datetime': 1651519474704, 'Bid': 1.05085}
# {'Datetime': 1651519474974, 'Bid': 1.24878}
# {'Datetime': 1651519475304, 'Bid': 1.0508600000000001}
# {'Datetime': 1651519475598, 'Bid': 1.24878}
# {'Datetime': 1651519475838, 'Bid': 1.0508600000000001}
# {'Datetime': 1651519476243, 'Bid': 1.05087}
# {'Datetime': 1651519476609, 'Bid': 1.24877}
# {'Datetime': 1651519477352, 'Bid': 1.24878}
# {'Datetime': 1651519477192, 'Bid': 1.05087}
# {'Datetime': 1651519477743, 'Bid': 1.24879}
# {'Datetime': 1651519477742, 'Bid': 1.05091}
# {'Datetime': 1651519479303, 'Bid': 1.05091}
# {'Datetime': 1651519479561, 'Bid': 1.05091}
# {'Datetime': 1651519480317, 'Bid': 1.05092}
# {'Datetime': 1651519480350, 'Bid': 1.24885}
# {'Datetime': 1651519480834, 'Bid': 1.05092}
# {'Datetime': 1651519480847, 'Bid': 1.24888}
# {'Datetime': 1651519481283, 'Bid': 1.05092}
# {'Datetime': 1651519481778, 'Bid': 1.05091}{'Datetime': 1651519481722, 'Bid': 1.24888}
#
# {'Datetime': 1651519482108, 'Bid': 1.05091}
# {'Datetime': 1651519482291, 'Bid': 1.24886}
# {'Datetime': 1651519483180, 'Bid': 1.05091}
# {'Datetime': 1651519483495, 'Bid': 1.05091}
# {'Datetime': 1651519484220, 'Bid': 1.05091}
# {'Datetime': 1651519484755, 'Bid': 1.0509}
# {'Datetime': 1651519484813, 'Bid': 1.24885}
# {'Datetime': 1651519485066, 'Bid': 1.24885}
# {'Datetime': 1651519485754, 'Bid': 1.05091}
# {'Datetime': 1651519485718, 'Bid': 1.24885}
# {'Datetime': 1651519486347, 'Bid': 1.05095}
# {'Datetime': 1651519486304, 'Bid': 1.2489000000000001}
# {'Datetime': 1651519486606, 'Bid': 1.05095}
# {'Datetime': 1651519486815, 'Bid': 1.2489000000000001}
# {'Datetime': 1651519487255, 'Bid': 1.05095}
# {'Datetime': 1651519487832, 'Bid': 1.05095}
# {'Datetime': 1651519488074, 'Bid': 1.05095}
# {'Datetime': 1651519489257, 'Bid': 1.05095}
# {'Datetime': 1651519489736, 'Bid': 1.05095}
# {'Datetime': 1651519489577, 'Bid': 1.2489000000000001}
# {'Datetime': 1651519490236, 'Bid': 1.05095}
# {'Datetime': 1651519490082, 'Bid': 1.2489000000000001}
# {'Datetime': 1651519490794, 'Bid': 1.05095}
# {'Datetime': 1651519490845, 'Bid': 1.24896}
# {'Datetime': 1651519491303, 'Bid': 1.24892}
# {'Datetime': 1651519491726, 'Bid': 1.05095}
# {'Datetime': 1651519491721, 'Bid': 1.24891}
# {'Datetime': 1651519491960, 'Bid': 1.05095}
# {'Datetime': 1651519492511, 'Bid': 1.05095}
# {'Datetime': 1651519493290, 'Bid': 1.05095}
# {'Datetime': 1651519495289, 'Bid': 1.24892}
# {'Datetime': 1651519495333, 'Bid': 1.05097}
# {'Datetime': 1651519495762, 'Bid': 1.0509600000000001}
# {'Datetime': 1651519496319, 'Bid': 1.2489000000000001}
# {'Datetime': 1651519496756, 'Bid': 1.24889}
# {'Datetime': 1651519496754, 'Bid': 1.05095}
# {'Datetime': 1651519497067, 'Bid': 1.05095}
# {'Datetime': 1651519498263, 'Bid': 1.24888}
# {'Datetime': 1651519498250, 'Bid': 1.05095}
# {'Datetime': 1651519498790, 'Bid': 1.05094}
# {'Datetime': 1651519499315, 'Bid': 1.24884}
# {'Datetime': 1651519499296, 'Bid': 1.05091}
# {'Datetime': 1651519499580, 'Bid': 1.24883}
# {'Datetime': 1651519499839, 'Bid': 1.05091}
# {'Datetime': 1651519500262, 'Bid': 1.24883}
# {'Datetime': 1651519500257, 'Bid': 1.05091}
# {'Datetime': 1651519501084, 'Bid': 1.24883}
# {'Datetime': 1651519501309, 'Bid': 1.0509}
# {'Datetime': 1651519501741, 'Bid': 1.24883}
# {'Datetime': 1651519502296, 'Bid': 1.05092}
# {'Datetime': 1651519502302, 'Bid': 1.24883}
# {'Datetime': 1651519502765, 'Bid': 1.05091}
# {'Datetime': 1651519502820, 'Bid': 1.24885}
# {'Datetime': 1651519503098, 'Bid': 1.0509}
# {'Datetime': 1651519503332, 'Bid': 1.24883}
# {'Datetime': 1651519503682, 'Bid': 1.0509}
# {'Datetime': 1651519503679, 'Bid': 1.24882}
# {'Datetime': 1651519503982, 'Bid': 1.24882}
# {'Datetime': 1651519504832, 'Bid': 1.0509}
# {'Datetime': 1651519504711, 'Bid': 1.24881}

# %%
trader.unsubscribe("EUR/USD")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/ratwc/Desktop/Senior-Project/aow-socket/Work Space Senior.ipynb Cell 5' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/ratwc/Desktop/Senior-Project/aow-socket/Work%20Space%20Senior.ipynb#ch0000027?line=0'>1</a> trader.unsubscribe("EUR/USD")
#
# File ~/Desktop/Senior-Project/aow-socket/libs/fxcm_libs/fxcm_rest_api_token.py:517, in Trader.unsubscribe(self, items)
#     <a href='file:///Users/ratwc/Desktop/Senior-Project/aow-socket/libs/fxcm_libs/fxcm_rest_api_token.py?line=514'>515</a> else:
#     <a href='file:///Users/ratwc/Desktop/Senior-Project/aow-socket/libs/fxcm_libs/fxcm_rest_api_token.py?line=515'>516</a>     self._forget(items)
# --> <a href='file:///Users/ratwc/Desktop/Senior-Project/aow-socket/libs/fxcm_libs/fxcm_rest_api_token.py?line=516'>517</a>     self.socketIO.off(items)
#     <a href='file:///Users/ratwc/Desktop/Senior-Project/aow-socket/libs/fxcm_libs/fxcm_rest_api_token.py?line=517'>518</a> return self.send("/trading/unsubscribe", {"models": items})
#
# AttributeError: 'Client' object has no attribute 'off'
# Exception in thread Thread-233873:
# Traceback (most recent call last):
#   File "/Users/ratwc/miniconda3/lib/python3.8/threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "/Users/ratwc/miniconda3/lib/python3.8/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/ratwc/miniconda3/lib/python3.8/site-packages/socketio/client.py", line 615, in _handle_eio_message
#     self._handle_event(pkt.namespace, pkt.id, pkt.data)
#   File "/Users/ratwc/miniconda3/lib/python3.8/site-packages/socketio/client.py", line 501, in _handle_event
#     r = self._trigger_event(data[0], namespace, *data[1:])
#   File "/Users/ratwc/miniconda3/lib/python3.8/site-packages/socketio/client.py", line 547, in _trigger_event
#     return self.handlers[namespace][event](*args)
#   File "/var/folders/4x/v5b3zg1x08s1gk73zyxj26mw0000gn/T/ipykernel_2671/4234402202.py", line 2, in get_tick
# TypeError: string indices must be integers
# Exception in thread Thread-234023:
# Traceback (most recent call last):
#   File "/Users/ratwc/miniconda3/lib/python3.8/threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "/Users/ratwc/miniconda3/lib/python3.8/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/ratwc/miniconda3/lib/python3.8/site-packages/socketio/client.py", line 615, in _handle_eio_message
#     self._handle_event(pkt.namespace, pkt.id, pkt.data)
#   File "/Users/ratwc/miniconda3/lib/python3.8/site-packages/socketio/client.py", line 501, in _handle_event
#     r = self._trigger_event(data[0], namespace, *data[1:])
#   File "/Users/ratwc/miniconda3/lib/python3.8/site-packages/socketio/client.py", line 547, in _trigger_event
#     return self.handlers[namespace][event](*args)
#   File "/var/folders/4x/v5b3zg1x08s1gk73zyxj26mw0000gn/T/ipykernel_2671/4234402202.py", line 2, in get_tick
# TypeError: string indices must be integers
# Exception in thread Thread-234093:
# Traceback (most recent call last):
#   File "/Users/ratwc/miniconda3/lib/python3.8/threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "/Users/ratwc/miniconda3/lib/python3.8/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/ratwc/miniconda3/lib/python3.8/site-packages/socketio/client.py", line 615, in _handle_eio_message
#     self._handle_event(pkt.namespace, pkt.id, pkt.data)
#   File "/Users/ratwc/miniconda3/lib/python3.8/site-packages/socketio/client.py", line 501, in _handle_event
#     r = self._trigger_event(data[0], namespace, *data[1:])
#   File "/Users/ratwc/miniconda3/lib/python3.8/site-packages/socketio/client.py", line 547, in _trigger_event
#     return self.handlers[namespace][event](*args)
#   File "/var/folders/4x/v5b3zg1x08s1gk73zyxj26mw0000gn/T/ipykernel_2671/4234402202.py", line 2, in get_tick
# TypeError: string indices must be integers
# Exception in thread Thread-234211:
# Traceback (most recent call last):
#   File "/Users/ratwc/miniconda3/lib/python3.8/threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "/Users/ratwc/miniconda3/lib/python3.8/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/ratwc/miniconda3/lib/python3.8/site-packages/socketio/client.py", line 615, in _handle_eio_message
#     self._handle_event(pkt.namespace, pkt.id, pkt.data)
#   File "/Users/ratwc/miniconda3/lib/python3.8/site-packages/socketio/client.py", line 501, in _handle_event
#     r = self._trigger_event(data[0], namespace, *data[1:])
#   File "/Users/ratwc/miniconda3/lib/python3.8/site-packages/socketio/client.py", line 547, in _trigger_event
#     return self.handlers[namespace][event](*args)
#   File "/var/folders/4x/v5b3zg1x08s1gk73zyxj26mw0000gn/T/ipykernel_2671/4234402202.py", line 2, in get_tick
# TypeError: string indices must be integers
# Exception in thread Thread-234258:
# Traceback (most recent call last):
#   File "/Users/ratwc/miniconda3/lib/python3.8/threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "/Users/ratwc/miniconda3/lib/python3.8/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/ratwc/miniconda3/lib/python3.8/site-packages/socketio/client.py", line 615, in _handle_eio_message
#     self._handle_event(pkt.namespace, pkt.id, pkt.data)
#   File "/Users/ratwc/miniconda3/lib/python3.8/site-packages/socketio/client.py", line 501, in _handle_event
#     r = self._trigger_event(data[0], namespace, *data[1:])
#   File "/Users/ratwc/miniconda3/lib/python3.8/site-packages/socketio/client.py", line 547, in _trigger_event
#     return self.handlers[namespace][event](*args)
#   File "/var/folders/4x/v5b3zg1x08s1gk73zyxj26mw0000gn/T/ipykernel_2671/4234402202.py", line 2, in get_tick
# TypeError: string indices must be integers
# Exception in thread Thread-235812:
# Traceback (most recent call last):
#   File "/Users/ratwc/miniconda3/lib/python3.8/threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "/Users/ratwc/miniconda3/lib/python3.8/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/ratwc/miniconda3/lib/python3.8/site-packages/socketio/client.py", line 615, in _handle_eio_message
#     self._handle_event(pkt.namespace, pkt.id, pkt.data)
#   File "/Users/ratwc/miniconda3/lib/python3.8/site-packages/socketio/client.py", line 501, in _handle_event
#     r = self._trigger_event(data[0], namespace, *data[1:])
#   File "/Users/ratwc/miniconda3/lib/python3.8/site-packages/socketio/client.py", line 547, in _trigger_event
#     return self.handlers[namespace][event](*args)
#   File "/var/folders/4x/v5b3zg1x08s1gk73zyxj26mw0000gn/T/ipykernel_2671/4234402202.py", line 2, in get_tick
# TypeError: string indices must be integers
# Exception in thread Thread-236115:
# Traceback (most recent call last):
#   File "/Users/ratwc/miniconda3/lib/python3.8/threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "/Users/ratwc/miniconda3/lib/python3.8/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/ratwc/miniconda3/lib/python3.8/site-packages/socketio/client.py", line 615, in _handle_eio_message
#     self._handle_event(pkt.namespace, pkt.id, pkt.data)
#   File "/Users/ratwc/miniconda3/lib/python3.8/site-packages/socketio/client.py", line 501, in _handle_event
#     r = self._trigger_event(data[0], namespace, *data[1:])
#   File "/Users/ratwc/miniconda3/lib/python3.8/site-packages/socketio/client.py", line 547, in _trigger_event
#     return self.handlers[namespace][event](*args)
#   File "/var/folders/4x/v5b3zg1x08s1gk73zyxj26mw0000gn/T/ipykernel_2671/4234402202.py", line 2, in get_tick
# TypeError: string indices must be integers
# Exception in thread Thread-236261:
# Traceback (most recent call last):
#   File "/Users/ratwc/miniconda3/lib/python3.8/threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "/Users/ratwc/miniconda3/lib/python3.8/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/ratwc/miniconda3/lib/python3.8/site-packages/socketio/client.py", line 615, in _handle_eio_message
#     self._handle_event(pkt.namespace, pkt.id, pkt.data)
#   File "/Users/ratwc/miniconda3/lib/python3.8/site-packages/socketio/client.py", line 501, in _handle_event
#     r = self._trigger_event(data[0], namespace, *data[1:])
#   File "/Users/ratwc/miniconda3/lib/python3.8/site-packages/socketio/client.py", line 547, in _trigger_event
#     return self.handlers[namespace][event](*args)
#   File "/var/folders/4x/v5b3zg1x08s1gk73zyxj26mw0000gn/T/ipykernel_2671/4234402202.py", line 2, in get_tick
# TypeError: string indices must be integers
# Exception in thread Thread-236422:
# Traceback (most recent call last):
#   File "/Users/ratwc/miniconda3/lib/python3.8/threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "/Users/ratwc/miniconda3/lib/python3.8/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/ratwc/miniconda3/lib/python3.8/site-packages/socketio/client.py", line 615, in _handle_eio_message
#     self._handle_event(pkt.namespace, pkt.id, pkt.data)
#   File "/Users/ratwc/miniconda3/lib/python3.8/site-packages/socketio/client.py", line 501, in _handle_event
#     r = self._trigger_event(data[0], namespace, *data[1:])
#   File "/Users/ratwc/miniconda3/lib/python3.8/site-packages/socketio/client.py", line 547, in _trigger_event
#     return self.handlers[namespace][event](*args)
#   File "/var/folders/4x/v5b3zg1x08s1gk73zyxj26mw0000gn/T/ipykernel_2671/4234402202.py", line 2, in get_tick
# TypeError: string indices must be integers
# Exception in thread Thread-236490:
# Traceback (most recent call last):
#   File "/Users/ratwc/miniconda3/lib/python3.8/threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "/Users/ratwc/miniconda3/lib/python3.8/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/ratwc/miniconda3/lib/python3.8/site-packages/socketio/client.py", line 615, in _handle_eio_message
#     self._handle_event(pkt.namespace, pkt.id, pkt.data)
#   File "/Users/ratwc/miniconda3/lib/python3.8/site-packages/socketio/client.py", line 501, in _handle_event
#     r = self._trigger_event(data[0], namespace, *data[1:])
#   File "/Users/ratwc/miniconda3/lib/python3.8/site-packages/socketio/client.py", line 547, in _trigger_event
#     return self.handlers[namespace][event](*args)
#   File "/var/folders/4x/v5b3zg1x08s1gk73zyxj26mw0000gn/T/ipykernel_2671/4234402202.py", line 2, in get_tick
# TypeError: string indices must be integers
# Exception in thread Thread-236621:
# Traceback (most recent call last):
#   File "/Users/ratwc/miniconda3/lib/python3.8/threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "/Users/ratwc/miniconda3/lib/python3.8/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/ratwc/miniconda3/lib/python3.8/site-packages/socketio/client.py", line 615, in _handle_eio_message
#     self._handle_event(pkt.namespace, pkt.id, pkt.data)
#   File "/Users/ratwc/miniconda3/lib/python3.8/site-packages/socketio/client.py", line 501, in _handle_event
#     r = self._trigger_event(data[0], namespace, *data[1:])
#   File "/Users/ratwc/miniconda3/lib/python3.8/site-packages/socketio/client.py", line 547, in _trigger_event
#     return self.handlers[namespace][event](*args)
#   File "/var/folders/4x/v5b3zg1x08s1gk73zyxj26mw0000gn/T/ipykernel_2671/4234402202.py", line 2, in get_tick
# TypeError: string indices must be integers
# Exception in thread Thread-236702:
# Traceback (most recent call last):
#   File "/Users/ratwc/miniconda3/lib/python3.8/threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "/Users/ratwc/miniconda3/lib/python3.8/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/ratwc/miniconda3/lib/python3.8/site-packages/socketio/client.py", line 615, in _handle_eio_message
#     self._handle_event(pkt.namespace, pkt.id, pkt.data)
#   File "/Users/ratwc/miniconda3/lib/python3.8/site-packages/socketio/client.py", line 501, in _handle_event
#     r = self._trigger_event(data[0], namespace, *data[1:])
#   File "/Users/ratwc/miniconda3/lib/python3.8/site-packages/socketio/client.py", line 547, in _trigger_event
#     return self.handlers[namespace][event](*args)
#   File "/var/folders/4x/v5b3zg1x08s1gk73zyxj26mw0000gn/T/ipykernel_2671/4234402202.py", line 2, in get_tick
# TypeError: string indices must be integers
# Exception in thread Thread-236794:
# Traceback (most recent call last):
#   File "/Users/ratwc/miniconda3/lib/python3.8/threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "/Users/ratwc/miniconda3/lib/python3.8/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/ratwc/miniconda3/lib/python3.8/site-packages/socketio/client.py", line 615, in _handle_eio_message
#     self._handle_event(pkt.namespace, pkt.id, pkt.data)
#   File "/Users/ratwc/miniconda3/lib/python3.8/site-packages/socketio/client.py", line 501, in _handle_event
#     r = self._trigger_event(data[0], namespace, *data[1:])
#   File "/Users/ratwc/miniconda3/lib/python3.8/site-packages/socketio/client.py", line 547, in _trigger_event
#     return self.handlers[namespace][event](*args)
#   File "/var/folders/4x/v5b3zg1x08s1gk73zyxj26mw0000gn/T/ipykernel_2671/4234402202.py", line 2, in get_tick
# TypeError: string indices must be integers

# %%
import math
import datetime as dt
current_date = math.floor(dt.datetime.now(dt.timezone.utc).timestamp())
current_date = (current_date - current_date % 86400) + 86400
from_date = (current_date - current_date % 86400) - 86400
start = dt.datetime.utcfromtimestamp(from_date)
end = dt.datetime.utcfromtimestamp(current_date)

str(start.timestamp())
# Out:
# 1651424400.0

# %%
x = trader.get_candles("EUR/USD", 'm5', num=2000)

# %%
x['candles'][-1:]
# Out:
# [[1651551000,
#   1.05163,
#   1.05162,
#   1.05163,
#   1.05158,
#   1.05176,
#   1.05176,
#   1.05177,
#   1.0517,
#   100]]
# packet queue is empty, aborting
# Websocket closed
# Websocket connected: gvheGyDo_k6ZSaYkAA4F
# Websocket closed
# ('Connection aborted.', ConnectionResetError(54, 'Connection reset by peer'))
# Websocket connected: EzuS_VSQO4ZFiSTMBmBh
# 2022-05-03 13:01:51,368 - d808da394895605e414394e79c1a3c9ffafad862_demo_ef860913 - ERROR - Failed to send request [{'models': 'Order'}]: ('Connection aborted.', ConnectionResetError(54, 'Connection reset by peer'))
# 2022-05-03 13:01:51,370 - d808da394895605e414394e79c1a3c9ffafad862_demo_ef860913 - ERROR - Error processing /trading/subscribe:{'status': False, 'data': "('Connection aborted.', ConnectionResetError(54, 'Connection reset by peer'))"}
# 2022-05-03 13:01:52,335 - d808da394895605e414394e79c1a3c9ffafad862_demo_ef860913 - ERROR - Error processing /trading/subscribe:{'status': False, 'data': 'Unauthorized'}
# 2022-05-03 13:01:53,175 - d808da394895605e414394e79c1a3c9ffafad862_demo_ef860913 - ERROR - Error processing /trading/subscribe:{'status': False, 'data': 'Unauthorized'}
# 2022-05-03 13:01:54,115 - d808da394895605e414394e79c1a3c9ffafad862_demo_ef860913 - ERROR - Error processing /trading/subscribe:{'status': False, 'data': 'Unauthorized'}
# 2022-05-03 13:01:54,963 - d808da394895605e414394e79c1a3c9ffafad862_demo_ef860913 - ERROR - Error processing /trading/subscribe:{'status': False, 'data': 'Unauthorized'}
# 2022-05-03 13:01:55,813 - d808da394895605e414394e79c1a3c9ffafad862_demo_ef860913 - ERROR - Error processing /trading/subscribe:{'status': False, 'data': 'Unauthorized'}
# 2022-05-03 13:11:01,405 - d808da394895605e414394e79c1a3c9ffafad862_demo_ef860913 - ERROR - Failed to send request [{'models': 'ClosedPosition'}]: HTTPSConnectionPool(host='api-demo.fxcm.com', port=443): Max retries exceeded with url: /trading/subscribe (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7f865a1ab820>: Failed to establish a new connection: [Errno 60] Operation timed out'))
# 2022-05-03 13:11:01,407 - d808da394895605e414394e79c1a3c9ffafad862_demo_ef860913 - ERROR - Error processing /trading/subscribe:{'status': False, 'data': "HTTPSConnectionPool(host='api-demo.fxcm.com', port=443): Max retries exceeded with url: /trading/subscribe (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7f865a1ab820>: Failed to establish a new connection: [Errno 60] Operation timed out'))"}
# 2022-05-03 13:11:02,297 - d808da394895605e414394e79c1a3c9ffafad862_demo_ef860913 - ERROR - Error processing /trading/subscribe:{'status': False, 'data': 'Unauthorized'}
# 2022-05-03 13:11:03,154 - d808da394895605e414394e79c1a3c9ffafad862_demo_ef860913 - ERROR - Error processing /trading/subscribe:{'status': False, 'data': 'Unauthorized'}
# 2022-05-03 13:11:04,007 - d808da394895605e414394e79c1a3c9ffafad862_demo_ef860913 - ERROR - Error processing /trading/subscribe:{'status': False, 'data': 'Unauthorized'}
# packet queue is empty, aborting
# Websocket closed
# ('Connection aborted.', ConnectionResetError(54, 'Connection reset by peer'))
# Websocket connected: nakFKQxooeCKvLhGAAOh
# Websocket closed
# ('Connection aborted.', ConnectionResetError(54, 'Connection reset by peer'))
# Websocket connected: 4UV9Y5NpLcPs7wXPEPQM
# 2022-05-03 13:38:12,337 - d808da394895605e414394e79c1a3c9ffafad862_demo_ef860913 - ERROR - Failed to send request [{'models': 'ClosedPosition'}]: ('Connection aborted.', ConnectionResetError(54, 'Connection reset by peer'))
# 2022-05-03 13:38:12,340 - d808da394895605e414394e79c1a3c9ffafad862_demo_ef860913 - ERROR - Error processing /trading/subscribe:{'status': False, 'data': "('Connection aborted.', ConnectionResetError(54, 'Connection reset by peer'))"}
# 2022-05-03 13:38:13,710 - d808da394895605e414394e79c1a3c9ffafad862_demo_ef860913 - ERROR - Error processing /trading/subscribe:{'status': False, 'data': 'Unauthorized'}
# 2022-05-03 13:38:14,558 - d808da394895605e414394e79c1a3c9ffafad862_demo_ef860913 - ERROR - Error processing /trading/subscribe:{'status': False, 'data': 'Unauthorized'}
# 2022-05-03 13:38:15,408 - d808da394895605e414394e79c1a3c9ffafad862_demo_ef860913 - ERROR - Error processing /trading/subscribe:{'status': False, 'data': 'Unauthorized'}
# packet queue is empty, aborting
# Websocket closed
# ('Connection aborted.', ConnectionResetError(54, 'Connection reset by peer'))
# Websocket connected: XzsVESntBQPx-tPIBxhr
# packet queue is empty, aborting
# Websocket closed
# ('Connection aborted.', ConnectionResetError(54, 'Connection reset by peer'))
# Websocket connected: -506F3dxS8Ze8tZzAATQ
# packet queue is empty, aborting
# Websocket closed
# ('Connection aborted.', ConnectionResetError(54, 'Connection reset by peer'))
# Websocket connected: CnNVpsOsIVjOMxfpAAKL
# packet queue is empty, aborting
# Websocket closed
# ('Connection aborted.', ConnectionResetError(54, 'Connection reset by peer'))
# Websocket connected: E8EthBchvMHHDsrYAAUN
# Websocket closed
# ('Connection aborted.', ConnectionResetError(54, 'Connection reset by peer'))
# Websocket connected: Bw18L-tuoIYqBdoWCEZX
# 2022-05-03 15:59:30,954 - d808da394895605e414394e79c1a3c9ffafad862_demo_ef860913 - ERROR - Error processing /trading/subscribe:{'status': False, 'data': 'Unauthorized'}
# 2022-05-03 15:59:31,821 - d808da394895605e414394e79c1a3c9ffafad862_demo_ef860913 - ERROR - Error processing /trading/subscribe:{'status': False, 'data': 'Unauthorized'}
# 2022-05-03 15:59:32,670 - d808da394895605e414394e79c1a3c9ffafad862_demo_ef860913 - ERROR - Error processing /trading/subscribe:{'status': False, 'data': 'Unauthorized'}
# 2022-05-03 15:59:33,770 - d808da394895605e414394e79c1a3c9ffafad862_demo_ef860913 - ERROR - Error processing /trading/subscribe:{'status': False, 'data': 'Unauthorized'}
# 2022-05-03 15:59:35,230 - d808da394895605e414394e79c1a3c9ffafad862_demo_ef860913 - ERROR - Error processing /trading/subscribe:{'status': False, 'data': 'Unauthorized'}
# Websocket closed
# Websocket connected: mPKBOaZGp8-vkFh8CE-6

# %%
import math
import datetime as dt
import pandas as pd
import json
import threading

db = mongo_connect() # mongodb connect 

save_seconds = 3600 # define the every time for save data to db
symbols_data = dict()

def get_ohlc(symbol, con):

    db_data = db['history'].find_one({ "Symbol": symbol })
    db_df = pd.DataFrame(json.loads(db_data['OHLC_M5']))
    db_df.index = db_df['Datetime']
    db_df = db_df.drop("Datetime", axis=1)

    # get missing data 
    db_last_date = math.floor(db_df[-1:].index[0] / 1000)
    db_last_date = db_last_date - db_last_date % 86400
    start = dt.datetime.utcfromtimestamp(db_last_date)
    current_date = math.floor(dt.datetime.now(dt.timezone.utc).timestamp())
    current_date = (current_date - current_date % 86400) + 86400
    end = dt.datetime.utcfromtimestamp(current_date)

    get_data = con.get_candles(symbol, period='m5', start=start, end=end)[['bidopen','bidclose','bidhigh','bidlow']]
    get_data.rename(columns = {'bidopen':'Open', 'bidhigh':'High', 'bidlow': 'Low', 'bidclose': 'Close'}, inplace = True)

    get_data.index = list(map(lambda time: math.floor(time / 10 ** 6), get_data.index.view(int)))

    # merge 2 dataframe 
    ohlc_m5 = pd.concat([db_df, get_data])
    ohlc_m5 = ohlc_m5[~ohlc_m5.index.duplicated(keep='last')]

    # store data in global variable
    global symbols_data
    ohlc_m5['Datetime'] = ohlc_m5.index
    ohlc_m5 = ohlc_m5.reset_index(drop=True)
    ohlc_m5_json = json.loads(ohlc_m5.to_json(orient='records'))
    symbols_data[symbol]['ohlc_m5'] = ohlc_m5_json

    print("Initial ", symbol, " seccess")

def manage_ohlc(tick, symbol, con):

     # check symbol is a new symbol to get ohlc or not
    global symbols_data, save_seconds
    if symbol not in symbols_data:
        symbols_data[symbol] = dict()
        symbols_data[symbol]['first_finished'] = False # check get first data has finished
        symbols_data[symbol]['ohlc_m5'] = None # initial ohlc 5 minute data of each symbol
        symbols_data[symbol]['save_time'] = 0 # recent save time

    # check first initial data has finished
    if symbols_data[symbol]['first_finished'] == False:
        symbols_data[symbol]['first_finished'] = True
        # initial first ohlc data
        thread_get_ohlc = threading.Thread(target=get_ohlc, args=(symbol, con,))
        thread_get_ohlc.start()
        thread_get_ohlc.join()
    
    # manage tick data on OHLC 5 minutes
    recent_ohlc_m5 = symbols_data[symbol]['ohlc_m5']
    if recent_ohlc_m5 != None:

        # get checking time to handle if new save time occur
        last_seconds = math.floor(int(tick[-1:].index.values[0]) / (10 ** 9))
        save_time = last_seconds - last_seconds % save_seconds  

        # convert tick to 1 minutes timeframe
        ohlc_m5 = convert_ohlc(tick)
        ohlc_m5['Datetime'] = ohlc_m5.index
        ohlc_m5 = ohlc_m5.reset_index(drop=True)

        last_steam = json.loads(ohlc_m5[-1:].to_json(orient='records'))[0] # tick steaming 
        last_recent = recent_ohlc_m5[len(recent_ohlc_m5) - 1] # lastest data store

        # update the lastest tick to global variable data 
        if last_steam['Datetime'] == last_recent['Datetime'] :
            recent_ohlc_m5[len(recent_ohlc_m5) - 1]['High'] = max(last_recent['High'], last_steam['High'])
            recent_ohlc_m5[len(recent_ohlc_m5) - 1]['Low'] = min(last_recent['Low'], last_steam['Low'])
            recent_ohlc_m5[len(recent_ohlc_m5) - 1]['Close'] = last_steam['Close']
        else :
            recent_ohlc_m5.append(last_steam.copy())

        symbols_data[symbol]['ohlc_m5'] = recent_ohlc_m5

        # set last steam tick to current time
        symbols_data[symbol]['last_seconds'] = last_seconds * 1000

        # # save data to DB
        # if symbols_data[symbol]['save_time'] != save_time:
    
        #     try :

        #         # drop last save data in db
        #         del_res = db['history'].delete_many({"Symbol": symbol})

        #         if del_res.acknowledged == True:
        #              # update save time
        #             symbols_data[symbol]['save_time'] = save_time
                    
        #             db['history'].insert_one({"Symbol": symbol, "OHLC_M5":  json.dumps(recent_ohlc_m5)})
        #             print(symbol, " was saved at timestamp > ", last_seconds)

        #     except: 
        #         # some error on save to db
        #         print("Can't update data of ", symbol ," to database")

# %%
def convert_ohlc(tick, tf="5Min"):
    
    ohlc_m5 = tick.resample(tf).ohlc()
    ohlc_m5.rename(columns = {'open':'Open', 'high':'High', 'low': 'Low', 'close': 'Close'}, inplace = True)

    return ohlc_m5

# %%
con.subscribe_market_data('EUR/USD', (get_tick, ))
# Out:
# Initial  EUR/USD  seccess

# %%
con.unsubscribe_market_data('EUR/USD')

# %%
def get_tick(price, df):
    # send to manage tick for send to client
    manage_ohlc(df['Bid'], price['Symbol'], con)

# %%
x = db['history'].find_one( {"Symbol": "EUR/USD"} )
x = json.loads(x['OHLC_M5'])

# %%
start = dt.datetime.utcfromtimestamp(math.floor(1651034100000 / 1000))
current_date = math.floor(dt.datetime.now(dt.timezone.utc).timestamp())
current_date = (current_date - current_date % 86400) + 86400
end = dt.datetime.utcfromtimestamp(current_date)

print(start, end)

get_data = con.get_candles("EUR/USD", period='m5', start=start, end=end)[['bidopen','bidclose','bidhigh','bidlow']]
get_data.rename(columns = {'bidopen':'Open', 'bidhigh':'High', 'bidlow': 'Low', 'bidclose': 'Close'}, inplace = True)
get_data
# Out:
# 2022-04-27 04:35:00 2022-04-28 00:00:00
#                         Open    Close     High      Low
# date
# 2022-04-27 04:35:00  1.06426  1.06419  1.06441  1.06416
# 2022-04-27 04:40:00  1.06420  1.06432  1.06443  1.06413
# 2022-04-27 04:45:00  1.06432  1.06460  1.06460  1.06431
# 2022-04-27 04:50:00  1.06461  1.06443  1.06461  1.06437
# 2022-04-27 04:55:00  1.06444  1.06491  1.06497  1.06440
# 2022-04-27 05:00:00  1.06491  1.06500  1.06505  1.06467
# 2022-04-27 05:05:00  1.06501  1.06491  1.06505  1.06485
# 2022-04-27 05:10:00  1.06492  1.06498  1.06506  1.06474
# 2022-04-27 05:15:00  1.06498  1.06527  1.06531  1.06490
# 2022-04-27 05:20:00  1.06526  1.06523  1.06534  1.06513
# 2022-04-27 05:25:00  1.06523  1.06530  1.06536  1.06516
# 2022-04-27 05:30:00  1.06530  1.06511  1.06541  1.06503
# 2022-04-27 05:35:00  1.06511  1.06499  1.06514  1.06488
# 2022-04-27 05:40:00  1.06498  1.06531  1.06540  1.06498
# 2022-04-27 05:45:00  1.06532  1.06500  1.06532  1.06489
# 2022-04-27 05:50:00  1.06500  1.06501  1.06505  1.06487
# 2022-04-27 05:55:00  1.06501  1.06499  1.06539  1.06470
# 2022-04-27 06:00:00  1.06499  1.06453  1.06512  1.06450
# 2022-04-27 06:05:00  1.06454  1.06348  1.06467  1.06346
# 2022-04-27 06:10:00  1.06348  1.06273  1.06351  1.06201
# 2022-04-27 06:15:00  1.06273  1.06269  1.06296  1.06251
# 2022-04-27 06:20:00  1.06269  1.06318  1.06325  1.06262

# %%
from pymongo import MongoClient
import pymongo

def mongo_connect():

    try:
         # Provide the mongodb atlas url to connect python to mongodb using pymongo
        CONNECTION_STRING = "mongodb+srv://aow:aow@aow.74qmf.mongodb.net/aow?retryWrites=true&w=majority"

        # Create a connection using MongoClient. You can import MongoClient or use pymongo.MongoClient
        client = MongoClient(CONNECTION_STRING)

        # Create the database for our example (we will use the same database throughout the tutorial
        return client['aow']

    except pymongo.errors.ServerSelectionTimeoutError as err:
        # return if cannot connect mongodb
        return -1

# %%
start = dt.datetime(2022, 4, 1)
end = dt.datetime(2022, 4, 27)
data = con.get_candles("EUR/USD", period='m5', start=start, end=end)[['bidopen','bidclose','bidhigh','bidlow']]
data.rename(columns = {'bidopen':'Open', 'bidhigh':'High', 'bidlow': 'Low', 'bidclose': 'Close'}, inplace = True)
data.index = list(map(lambda time: math.floor(time / 10 ** 6), data.index.view(int)))
data['Datetime'] = data.index
data = data.reset_index(drop=True)
data = json.loads(data.to_json(orient='records'))

# %%
x = db['history'].find_one( {"Symbol": "EUR/USD"} )
x = json.loads(x['OHLC_M5'])

# %%
len(x)
# Out:
# 18181

# %%
import copy
# the comment timeframe feature will update in the future
timeframe = {
    # "1Min": 1,
    "5Min": 5,
    "10Min": 10,
    "15Min": 15,
    "30Min": 30,
    "45Min": 45,
    "1H": 60,
    "2H": 120,
    "3H": 180,
    "4H": 240,
    "8H": 480,
    "12H": 720,
    "1D": 1440,
    # "1W": 10080, # need to have offset because the present start of the week is thuesday
    # "1M": "month"
}

def ohlc_to_ohlc(data, from_tf, to_tf):

    try: 

        if timeframe[from_tf] > timeframe[to_tf]:
            print("to timeframe must be greater than from timeframe")
            return 0

        elif timeframe[from_tf] == timeframe[to_tf]:
            return pd.DataFrame(data).set_index('Datetime')

        # copy the data to new variable to prevent data change by reference
        ohlc_data = copy.deepcopy(data)
        # sort with accending time 
        ohlc_data = sorted(ohlc_data, key=lambda d: d['Datetime'], reverse=False) 
        # change time from milliseconds to seconds 
        for d in ohlc_data: d['Datetime'] = math.floor(d['Datetime'] / 1000)

        tf_seconds = timeframe[to_tf] * 60

        for d in ohlc_data: d['Datetime'] = d['Datetime'] - d['Datetime'] % tf_seconds

        # find the interval to time
        start_list = [0]
        [start_list.append(idx + 1) for idx in range(len(ohlc_data[:-1])) if ohlc_data[idx]['Datetime'] != ohlc_data[idx + 1]['Datetime']]
        start_list.append(len(ohlc_data))

        new_ohlc = []
        def form_data(idx):

            temp_dict = {}
            tf_data = ohlc_data[start_list[idx]: start_list[idx + 1]]

            # add data to dict
            temp_dict['Datetime'] = tf_data[0]['Datetime'] * 1000
            temp_dict['Open'] = tf_data[0]['Open']
            temp_dict['High'] = max(tf_data, key=lambda d:d['High'])['High']
            temp_dict['Low'] = min(tf_data, key=lambda d:d['Low'])['Low']
            temp_dict['Close'] = tf_data[len(tf_data) - 1]['Close']

            new_ohlc.append(temp_dict)

        list(map(form_data, range(len(start_list[:-1]))))

        return pd.DataFrame(new_ohlc).set_index('Datetime')

    except: 

        print("Some Error on convert ohlc")

# %%
ohlc_to_ohlc(x, "5Min", "1D")
# Out:
#                   Open     High      Low    Close
# Datetime
# 1643673600000  1.12286  1.12781  1.12202  1.12722
# 1643760000000  1.12723  1.13293  1.12661  1.12988
# 1643846400000  1.12988  1.14507  1.12663  1.14349
# 1643932800000  1.14351  1.14831  1.14108  1.14500
# 1644105600000  1.14616  1.14686  1.14507  1.14539
# ...                ...      ...      ...      ...
# 1650758400000  1.08437  1.08509  1.07952  1.08086
# 1650844800000  1.08087  1.08113  1.06959  1.07119
# 1650931200000  1.07118  1.07380  1.06345  1.06419
# 1651017600000  1.06420  1.06541  1.05221  1.05537
# 1651104000000  1.05536  1.05536  1.04801  1.05270
#
# [75 rows x 4 columns]
# packet queue is empty, aborting
# packet queue is empty, aborting
# packet queue is empty, aborting

# %%
x[-1:]
# Out:
# [{'Open': 1.05291,
#   'Close': 1.0527,
#   'High': 1.05291,
#   'Low': 1.05254,
#   'Datetime': 1651129500000}]

# %%
gg = [1, 2, 3, 4]
gg[-2:-1][0]
# Out:
# 3
# packet queue is empty, aborting

# %%
import math
lastest_close = con.get_candles('EUR/USD', period='H1', number=1)
lastest_datetime = math.floor(lastest_close['bidclose'].index.view(int) / 10 ** 6)
lastest_price = lastest_close['bidclose'].values[0]
lastest_price
# Out:
# 1.05407

# %%
import feedparser
NewsFeed = feedparser.parse("https://th.investing.com/rss/news_1.rss")

# %%
forex_news = []
for idx, news in enumerate(NewsFeed.entries):
    forex_news.append( {"id": idx + 1, "topic": news['title'], "published": news['published'], "link": news['link'], "image_url": news['links'][0]['href']} )
forex_news
# Out:
# [{'id': 1,
#   'topic': 'ดอลลาร์ผ่อนคลายเล็กน้อย หลังนักลงทุนบางส่วนขายทำกำไร',
#   'published': '2022-04-29 08:37:36',
#   'link': 'https://th.investing.com/news/forex-news/article-73256',
#   'image_url': 'https://i-invdn-com.investing.com/news/LYNXNPEE9L0PN_M.jpg'},
#  {'id': 2,
#   'topic': 'ดอลลาร์อ่อนค่า แต่ยังใกล้ระดับสูงในรอบสองทศวรรษ',
#   'published': '2022-04-29 04:56:20',
#   'link': 'https://th.investing.com/news/forex-news/article-73235',
#   'image_url': 'https://i-invdn-com.investing.com/news/LYNXMPECAD01M_M.jpg'},
#  {'id': 3,
#   'topic': 'ดอลลาร์แตะระดับสูงสุดในรอบ 20 ปี เทียบกับค่าเงินเยนที่ 130.71',
#   'published': '2022-04-28 08:40:30',
#   'link': 'https://th.investing.com/news/forex-news/article-73089',
#   'image_url': 'https://i-invdn-com.investing.com/news/LYNXMPED6618D_M.jpg'},
#  {'id': 4,
#   'topic': 'ดอลลาร์ขึ้นใกล้ระดับสูงสุดสองทศวรรษ BOJ มอบการตัดสินใจนโยบายล่าสุด',
#   'published': '2022-04-28 06:13:06',
#   'link': 'https://th.investing.com/news/forex-news/article-73057',
#   'image_url': 'https://th.investing.com/news/forex-news/article-73057'},
#  {'id': 5,
#   'topic': 'เงินบาทอ่อนค่ารุนแรงที่ 34.415 หลังดัชนีดอลลาร์แตะระดับสูงสุดในรอบ 5 ปี',
#   'published': '2022-04-28 02:50:24',
#   'link': 'https://th.investing.com/news/forex-news/article-73049',
#   'image_url': 'https://th.investing.com/news/forex-news/article-73049'},
#  {'id': 6,
#   'topic': 'เงินดอลลาร์แข็งค่าขึ้นสูงสุดในรอบ 2 ปี ทุกคนหนีเข้าหาทรัพย์สินปลอดภัย',
#   'published': '2022-04-27 07:14:30',
#   'link': 'https://th.investing.com/news/forex-news/article-72917',
#   'image_url': 'https://th.investing.com/news/forex-news/article-72917'},
#  {'id': 7,
#   'topic': 'ดอลล่าร์ทะยาน แข็งค่าที่สุดนับตั้งแต่ปี 2015',
#   'published': '2022-04-27 04:46:32',
#   'link': 'https://th.investing.com/news/forex-news/article-72894',
#   'image_url': 'https://th.investing.com/news/forex-news/article-72894'},
#  {'id': 8,
#   'topic': 'GBP/USD ร่วงลง 1% เนื่องจากเทรดเดอร์ผ่อนคลายเดิมผันต่อ BoE',
#   'published': '2022-04-27 02:29:55',
#   'link': 'https://th.investing.com/news/forex-news/article-72866',
#   'image_url': 'https://i-invdn-com.investing.com/news/LYNXNPEC8C0MQ_M.jpg'},
#  {'id': 9,
#   'topic': 'ดอลลาร์ทรงตัวใกล้ระดับสูงสุดในรอบสองปี ล็อกดาวน์ในจีนกระทบการเติบโต',
#   'published': '2022-04-26 07:01:48',
#   'link': 'https://th.investing.com/news/forex-news/article-72783',
#   'image_url': 'https://i-invdn-com.investing.com/news/LYNXNPEC220WE_M.jpg'},
#  {'id': 10,
#   'topic': 'ดอลลาร์ปรับตัวลง แต่ยังใกล้ระดับสูงสุดในรอบ 2 ปี บาทอ่อนสุดในรอบ 5 ปี',
#   'published': '2022-04-26 04:29:22',
#   'link': 'https://th.investing.com/news/forex-news/article-72756',
#   'image_url': 'https://i-invdn-com.investing.com/news/LYNXMPECAD01M_M.jpg'}]

# %%
NewsFeed.entries[1]
# Out:
# {'links': [{'length': '32864',
#    'type': 'image/jpeg',
#    'href': 'https://i-invdn-com.investing.com/news/LYNXMPECAD01M_M.jpg',
#    'rel': 'enclosure'},
#   {'rel': 'alternate',
#    'type': 'text/html',
#    'href': 'https://th.investing.com/news/forex-news/article-73235'}],
#  'title': 'ดอลลาร์อ่อนค่า แต่ยังใกล้ระดับสูงในรอบสองทศวรรษ',
#  'title_detail': {'type': 'text/plain',
#   'language': None,
#   'base': 'https://th.investing.com/rss/news_1.rss',
#   'value': 'ดอลลาร์อ่อนค่า แต่ยังใกล้ระดับสูงในรอบสองทศวรรษ'},
#  'published': '2022-04-29 04:56:20',
#  'published_parsed': time.struct_time(tm_year=2022, tm_mon=4, tm_mday=29, tm_hour=4, tm_min=56, tm_sec=20, tm_wday=4, tm_yday=119, tm_isdst=0),
#  'authors': [{'name': 'Investing.com'}],
#  'author': 'Investing.com',
#  'author_detail': {'name': 'Investing.com'},
#  'link': 'https://th.investing.com/news/forex-news/article-73235'}

# %%
import investpy
import datetime as dt

# define day interval
day_interval_past = 7
day_interval_future = 15

def get_economic_calendar(symbol):

    day_now = dt.datetime.now()
    day_past = (day_now - dt.timedelta(days=day_interval_past)).strftime("%d/%m/%Y")
    day_future = (day_now + dt.timedelta(days=day_interval_future)).strftime("%d/%m/%Y")

    economic_news = investpy.news.economic_calendar(from_date=str(day_past), to_date=str(day_future))

    economic_news = economic_news[(economic_news['currency'] == symbol.split("/")[0]) | (economic_news['currency'] == symbol.split("/")[1])][["date", "time", "currency", "importance", "event", "actual", "forecast", "previous"]]
    # economic_news = economic_news.reset_index(drop=True)
    # economic_news_json = economic_news.to_json(orient='records')

    return economic_news

# %%
x = get_economic_calendar("EUR/USD")

# %%
x['time'].values
# Out:
# array(['06:00', '12:30', '12:30', '12:30', '13:00', '13:00', '13:45',
#        '13:45', '13:45', '13:45', '14:00', '15:30', '19:45', '20:00',
#        '20:00', '20:00', '21:00', '21:00', '21:00', '22:30', '22:30',
#        '23:00', '01:00', '11:30', '11:30', '12:00', '12:00', '13:00',
#        '13:00', '13:00', '14:00', '14:00', '15:00', '15:00', '16:00',
#        '16:00', '16:00', '16:00', '16:00', '16:00', '16:00', '16:30',
#        '17:00', '17:00', '17:00', '17:00', '18:40', '19:30', '19:55',
#        '21:00', '21:00', '22:30', '23:00', '23:20', '00:00', '00:00',
#        '00:00', '00:20', '02:00', '03:30', '06:00', '13:00', '13:00',
#        '13:00', '13:00', '13:00', '13:00', '14:15', '15:00', '16:10',
#        'Tentative', '17:00', '17:00', '17:00', '17:00', '18:00', '18:00',
#        '18:00', '18:00', '18:00', '18:30', '19:20', '19:30', '19:30',
#        '19:30', '19:30', '19:30', '19:30', '19:30', '19:30', '19:30',
#        '21:30', '21:30', '21:30', '21:30', '21:30', '21:30', '21:30',
#        '21:30', '21:30', '21:30', '22:00', '22:30', '23:00', '00:01',
#        '01:00', '12:00', '15:00', '17:00', '17:00', '17:00', '17:00',
#        '17:00', '17:00', '17:00', '17:00', '17:00', '17:30', '18:00',
#        '19:30', '19:30', '19:30', '19:30', '19:30', '19:30', '19:30',
#        '21:00', '21:30', '22:30', '22:30', '23:00', '00:00', '02:00',
#        '12:00', '13:45', '13:45', '13:45', '13:45', '14:00', '14:00',
#        '14:00', '14:00', '14:00', '14:00', '14:00', '14:00', '14:00',
#        '16:00', '16:00', '19:30', '19:30', '21:00', '21:00', '21:00',
#        '21:00', '21:00', '22:00', '23:00', '23:00', '00:00', '00:00',
#        '02:30', '02:30', '02:30', '02:30', '02:30', '02:30', '02:30',
#        '02:30', '02:30', '02:30', '02:30', '02:30', '12:00', '12:30',
#        '12:30', '12:30', '13:00', '13:00', '15:20', '16:00', '16:00',
#        '16:30', '16:30', '17:30', '18:00', '19:30', '19:55', '20:00',
#        '20:00', '20:00', '22:10', '22:30', '22:30', '03:00', '03:00',
#        '03:00', '03:00', '12:00', '12:30', '13:30', '14:00', '14:30',
#        '14:30', '14:30', '14:30', '15:00', '15:00', '15:00', '16:00',
#        '16:00', '16:00', '16:00', '16:00', '16:00', '16:00', '16:00',
#        '16:00', '16:00', '16:30', '19:00', '19:30', '19:30', '19:30',
#        '19:30', '19:30', '19:55', '20:15', '20:15', '20:15', '20:15',
#        '21:00', '21:00', '21:00', '22:30', '00:00', '01:00', '01:30',
#        '03:30', '12:00', '12:00', '13:00', '13:00', '13:00', '13:00',
#        '13:00', '13:00', '14:00', '14:00', '14:00', '14:00', '14:00',
#        '15:00', '16:00', '16:00', '16:00', '16:00', '16:00', '16:00',
#        '16:00', 'Tentative', '16:00', '16:00', '16:30', '18:00', '18:00',
#        '18:00', '18:00', '18:00', '19:30', '19:30', '19:30', '19:30',
#        '19:30', '19:30', '21:30', '21:30', '21:30', '21:30', '21:30',
#        '21:30', '21:30', '21:30', '21:30', '21:30', '22:00', '22:10',
#        '23:00', '23:23', '00:00', '11:30', '14:05', '16:00', '16:00',
#        'Tentative', '16:00', '16:00', '16:00', '18:30', '19:30', '19:30',
#        '19:30', '19:30', '19:30', '19:30', '19:30', '19:30', '19:30',
#        '19:30', '21:00', '21:00', '21:00', '21:30', '22:30', '22:30',
#        '23:20', '00:00', '11:30', '12:00', '12:00', '13:00', '13:00',
#        '13:30', '16:00', '16:00', '18:00', '18:45', '19:00', '21:00',
#        '00:00', '00:00', '02:30', '02:30', '02:30', '02:30', '02:30',
#        '02:30', '02:30', '02:30', '02:30', '02:30', '02:30', '02:30',
#        '13:00', '13:00', '15:00', '15:00', '15:00', '17:00', '17:00',
#        '19:30', '20:00', '12:00', '12:00', '12:00', '12:00', '13:45',
#        '14:15', '14:15', '14:15', '14:30', '14:30', '14:30', '15:00',
#        '15:00', '15:00', '19:30', '20:45', '20:45', '20:45', '21:00',
#        '21:00', '21:00', '21:00', '21:00', '12:00', '13:00', '13:00',
#        '13:00', '13:45', '19:30', '19:30', '19:30', '19:30', '01:00',
#        '15:00', '15:00', '15:00', '15:00', '19:30', '19:30', '19:30',
#        '19:30', '19:30', '19:30', '19:30', '21:00', '21:00', '22:00',
#        '22:00', '12:00', '12:00', '14:00', '15:00', '15:00', '15:00',
#        '15:00', '17:00', '17:00', '19:30', '19:30', '19:30', '19:30',
#        '19:30', '19:30', '19:30', '19:30', '19:30', '21:00', '21:00',
#        '21:00', '21:00', '21:00', '05:00', '15:40', '11:30', '13:00',
#        '13:00', '14:00', '14:00', '14:00', '15:30', '15:30', '16:00',
#        '16:00', '16:00', '16:00', '16:00', '16:00', '16:00', '16:00',
#        '16:30', '16:30', '17:00', '17:00', '19:00', '19:00', '19:00',
#        '19:00', '23:23', '23:23', '11:30', '12:00', '12:00', '12:00',
#        '13:00', '13:45', '13:45', '13:45', '14:55', '14:55', '14:55',
#        '14:55', '15:00', '15:00', '15:00', '16:00', '16:00', '16:00',
#        '16:00', '16:00', '16:00', '16:00', '16:00', '16:00', '17:00',
#        '17:00', '17:00', '20:00', '20:00', '20:00', '20:00', '20:00',
#        '20:00', '20:45', '21:00', '21:30'], dtype=object)

# %%
import json
